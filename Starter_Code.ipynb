# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
app_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
app_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `app_replace`
app_values = app_df['APPLICATION_TYPE'].value_counts()
app_replace = app_values[app_values < 500].index.tolist()

# Replace in dataframe
for app in app_replace:
    app_df['APPLICATION_TYPE'] = app_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
app_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
value = app_df['CLASSIFICATION'].value_counts()
filter_value = value[value > 1]
print(filter_value)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_values = app_df['CLASSIFICATION'].value_counts()
class_replace = class_values[class_values < 1883].index.tolist()

# Replace in dataframe
for cls in class_replace:
    app_df['CLASSIFICATION'] = app_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
app_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
print(app_df['INCOME_AMT'].dtype)
# Out:
# object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_numeric_df = pd.get_dummies(app_df, columns=['INCOME_AMT', 'APPLICATION_TYPE', 'CLASSIFICATION'])

# %%
app_numeric_df.head()
# Out:
#         AFFILIATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent    ProductDev   Association       1
# 1       Independent  Preservation  Co-operative       1
# 2  CompanySponsored    ProductDev   Association       1
# 3  CompanySponsored  Preservation         Trust       1
# 4       Independent     Heathcare         Trust       1
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL  INCOME_AMT_0  \
# 0                      N     5000              1             1
# 1                      N   108590              1             0
# 2                      N     5000              0             1
# 3                      N     6692              1             0
# 4                      N   142590              1             0
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  ...  APPLICATION_TYPE_T5  \
# 0                  0                       0  ...                    0
# 1                  1                       0  ...                    0
# 2                  0                       0  ...                    1
# 3                  0                       1  ...                    0
# 4                  0                       0  ...                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    CLASSIFICATION_C1000  CLASSIFICATION_C1200  CLASSIFICATION_C2000  \
# 0                     1                     0                     0
# 1                     0                     0                     1
# 2                     0                     0                     0
# 3                     0                     0                     1
# 4                     1                     0                     0
#
#    CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_Other
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     1                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
# [5 rows x 31 columns]

# %%
from scipy.sparse import random
# Split our preprocessed data into our features and target arrays
y = app_numeric_df['IS_SUCCESSFUL']
x = app_numeric_df.drop(columns =['AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', 'SPECIAL_CONSIDERATIONS', 'IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(x_train)

# Scale the data
X_train_scaled = X_scaler.transform(x_train)
X_test_scaled = X_scaler.transform(x_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=25))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=25))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 80)                2080
#
#  dense_40 (Dense)            (None, 30)                2430
#
#  dense_41 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 4541 (17.74 KB)
# Trainable params: 4541 (17.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6434 - accuracy: 0.6161
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6377 - accuracy: 0.6228
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6377 - accuracy: 0.6223
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6370 - accuracy: 0.6226
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6362 - accuracy: 0.6249
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6362 - accuracy: 0.6246
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6351 - accuracy: 0.6243
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6354 - accuracy: 0.6263
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6349 - accuracy: 0.6238
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6350 - accuracy: 0.6241
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6347 - accuracy: 0.6253
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6345 - accuracy: 0.6248
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6345 - accuracy: 0.6257
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6347 - accuracy: 0.6254
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6343 - accuracy: 0.6229
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6343 - accuracy: 0.6260
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6344 - accuracy: 0.6268
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6341 - accuracy: 0.6259
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.